# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np

# https://www.kaggle.com/datasets/sumairaziz/vibration-faults-dataset-for-rotating-machines

data = loadmat('assets/vibration_dataset/versions/1/Healthy/H1.mat')

print(data.keys())
signal = data['H']
print(signal.shape)
print(signal)
# sygnał jest wyrażony w trzech płaszczyznach X, Y, Z
x_signal = signal[:,0]
y_signal = signal[:,1]
z_signal = signal[:,2]

plt.figure(figsize=(12, 6))
plt.plot(x_signal)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'H'])
# (5000, 3)
# [[-0.33616589  0.28115763 -2.24713208]
#  [-0.14378816  0.04017759  1.10281961]
#  [ 1.82697372  0.41116059  1.14866405]
#  ...
#  [-0.38046115  1.79492565 -0.99337681]
#  [-0.30433534 -0.59299497  0.73377308]
#  [-1.21640785  0.92481604 -0.08338467]]
