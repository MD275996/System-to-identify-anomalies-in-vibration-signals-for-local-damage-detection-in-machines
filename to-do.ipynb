# %% [markdown]
# # To Do List
#
# - Dodać Selektor CVB
# - Poprawić funkcje selektorów aby przyjmowały macierz już po transformacie fouriera
# - Narysować wszystkie selektory na jednym wykresie
# - Dowiedzieć się więcej na temat sygnałów i spektrogramów
# - Można z data_simulator.ipynb zrobić skrypt .py, który będzie od razu zapisywał do pliku (do poprawki jeszcze)
