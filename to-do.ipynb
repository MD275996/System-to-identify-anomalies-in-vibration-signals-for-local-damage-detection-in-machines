# %% [markdown]
# # To Do List
# - Dodać filtrację sygnału po obliczeniu selektorów
# - Dodać obsługiwanie plików na stronie analyze
# - Napisać funkcję analyze która przeprowadzi analizę dla wybranego pliku
#
# - Strona:
#     - Umożliwić zmianę treści strony w zależności od wykonywanych funkcji (bez zmiany adresu)
#     - Menu:
#         - Sidemenu będzie wyświetlane cały czas
#         - Obecna strona ma być podświetlona
#         - Styl: ikonka plus tytuł
#     - Load Data:
#         - Wyśrodkować wszystko
#         - Dodać pole do dropu
#         - Oprócz pola do dropu dodać button
#
#
# Rozdziały pracy
# - Wstęp (powstanie na końcu)
# - Metody statystyczne do identyfikacji pasm informacyjnych
#     - Statystyki wykorzystywane jako selektory (czym jest spectrogram, zastosowane statystyki, czym jest selektor)
#     - Model sygnału drganiowego (opisać model sygnału, wyrysować, spektrogramy dla nich)
# - Analiza danych z zaadoptowanego modelu
#     - sprawdzenie który selektor jest lepszy za pomocą parametru wyznaczonego dla danych po filtracji
# - Aplikacja webowa do identyfikacji pasm informacyjnych z sygnału
#     - Dokumentacja dla użytkownika z printscreenami (wszystko musi być wizualnie gotowe)
# - Podsumowanie (powstanie na końcu)
