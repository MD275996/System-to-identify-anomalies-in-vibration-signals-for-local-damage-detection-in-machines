# %% [markdown]
# # To Do List
#
# - Wykonać dobry spectogram dla zdrowych danych
# - Wykonać dobry spectogram dla uszkodzonych danych
# - Spróbować wygenerować inne dane dla spectrogramu
# - Zabrać się za pisanie strony lub stworzenie mockupu
# - Dowiedzieć się więcej na temat sygnałów i spektrogramów
# - W nowym pliku zapisać funkcje selektorów
# - wypróbować na zestawie danych z kaggle
